# %% [markdown]
# # Slingshot Take Home Project - ML Model Creation

# %% [markdown]
# #### DataFrame Setup

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# from sklearn.externals import joblib
import joblib
from sklearn import tree

# Data Cleaning
hackClub_data = pd.read_csv('cleanedHackClubData.csv')
hackClub_data = hackClub_data.dropna()
df = hackClub_data[['Streak','GHFollowers','GHFollowing','GHContributions','Result']]
df = df.dropna()
df = df.reset_index()
hackClub_data = hackClub_data.reset_index()
df['Streak'] = df['Streak'].map(lambda x: x.rstrip('-day streak'))
df['GHContributions'] = df['GHContributions'].map(lambda x: x.rstrip('\n      contributions\n        in the last year'))
df = df.replace(',','', regex=True)

# Final Data Processing & Creation
inputD = df.drop(columns=['Result'])
outputD = df['Result']


# # Split data into test/train sets
#inputD_train,inputD_test,outputD_train,outputD_test = train_test_split(inputD,outputD,test_size=0.2)


# # Creating Model
# model = DecisionTreeClassifier()
# model.fit(inputD_train,outputD_train)

# Model Persistence
# joblib.dump(model,'slingshot-recommender.joblib')
model = joblib.load("slingshot-recommender.joblib")
modelInput = inputD

# Predictions + Merging Results To A Table
predictions = model.predict(modelInput)
modelInput['Results'] = predictions

#Result Cleaning 
finalResults = pd.merge(modelInput, hackClub_data, how="left", on="index")
finalResults = finalResults.loc[:,~finalResults.columns.duplicated()].copy()
finalResults = finalResults.drop(columns=['Streak_x','GHFollowers_x','GHFollowing_x','GHContributions_x'])

# Data Output
finalResults
# Out:
#     index Results            main page username  \
# 0       1     Yes          @sikebot0Wed, Oct 12
# 1       2     Yes                    @la15:23am
# 2       4     Yes       @StuntStorm1Fri, Oct 14
# 3       7     Yes           @Lucas7+Wed, Oct 12
# 4       8     Yes            @caleb0Thu, Oct 13
# 5      10     Yes         @Skyascii0Thu, Oct 13
# 6      14     Yes        @javierzaleta7+12:27am
# 7      15     Yes                  @Omay31:05am
# 8      16     Yes                @aaryan12:34pm
# 9      18     Yes  @abolunthompson7+Mon, Oct 10
# 10     19     Yes            @linus0Tue, Oct 11
# 11     21     Yes     @hugo.y.hu9350Tue, Oct 11
# 12     22     Yes            @ryan7+Tue, Oct 11
# 13     23     Yes         @matthew7+Tue, Oct 11
# 14     24     Yes              @jc7+Wed, Oct 12
# 15     25     Yes     @christina6950Wed, Oct 12
# 16     26     Yes              @Sam1Wed, Oct 12
# 17     27     Yes    @rajanagarwal7+Wed, Oct 12
# 18     29     Yes      @swarnya2467+Thu, Oct 13
# 19     30     Yes         @sampoder0Thu, Oct 13
# 20     31     Yes              @ced0Thu, Oct 13
# 21     32     Yes           @thrzl7+Thu, Oct 13
# 22     34     Yes          @maggie7+Thu, Oct 13
# 23     35     Yes   @clairebookworm0Thu, Oct 13
# 24     38     Yes             @ian7+Fri, Oct 14
# 25     39     Yes            @toby7+Fri, Oct 14
# 26     42     Yes           @kaidevrim7+10:29pm
# 27     43     Yes                 @zrl7+11:27pm
# 28     44     Yes                @suhas112:30am
# 29     47     Yes                 @Snow111:18am
#
#                           main page username-href Hack Club Username  \
# 0          https://scrapbook.hackclub.com/sikebot            sikebot
# 1               https://scrapbook.hackclub.com/la                 la
# 2       https://scrapbook.hackclub.com/StuntStorm         StuntStorm
# 3            https://scrapbook.hackclub.com/Lucas              Lucas
# 4            https://scrapbook.hackclub.com/caleb              caleb
# 5         https://scrapbook.hackclub.com/Skyascii           Skyascii
# 6     https://scrapbook.hackclub.com/javierzaleta       javierzaleta
# 7             https://scrapbook.hackclub.com/Omay               Omay
# 8           https://scrapbook.hackclub.com/aaryan             aaryan
# 9   https://scrapbook.hackclub.com/abolunthompson     abolunthompson
# 10           https://scrapbook.hackclub.com/linus              linus
# 11    https://scrapbook.hackclub.com/hugo.y.hu935       hugo.y.hu935
# 12            https://scrapbook.hackclub.com/ryan               ryan
# 13         https://scrapbook.hackclub.com/matthew            matthew
# 14              https://scrapbook.hackclub.com/jc                 jc
# 15    https://scrapbook.hackclub.com/christina695       christina695
# 16             https://scrapbook.hackclub.com/Sam                Sam
# 17    https://scrapbook.hackclub.com/rajanagarwal       rajanagarwal
# 18      https://scrapbook.hackclub.com/swarnya246         swarnya246
# 19        https://scrapbook.hackclub.com/sampoder           sampoder
# 20             https://scrapbook.hackclub.com/ced                ced
# 21           https://scrapbook.hackclub.com/thrzl              thrzl
# 22          https://scrapbook.hackclub.com/maggie             maggie
# 23  https://scrapbook.hackclub.com/clairebookworm     clairebookworm
# 24             https://scrapbook.hackclub.com/ian                ian
# 25            https://scrapbook.hackclub.com/toby               toby
# 26       https://scrapbook.hackclub.com/kaidevrim          kaidevrim
# 27             https://scrapbook.hackclub.com/zrl                zrl
# 28           https://scrapbook.hackclub.com/suhas              suhas
# 29            https://scrapbook.hackclub.com/Snow               Snow
#
#           Streak_y                       GitHub Link-href  \
# 0     0-day streak          https://github.com/sikethedev
# 1     1-day streak                https://github.com/lxjv
# 2     1-day streak         https://github.com/StuntStorm/
# 3    25-day streak           https://github.com/LucasHT22
# 4     0-day streak             https://github.com/cjdenio
# 5     0-day streak         https://github.com/savioxavier
# 6   385-day streak        https://github.com/javierzaleta
# 7     3-day streak             https://github.com/Omay238
# 8     1-day streak        https://github.com/aaryanporwal
# 9    10-day streak       https://github.com/BolunThompson
# 10    0-day streak         https://github.com/LinusSkucas
# 11    0-day streak             https://github.com/Hugoyhu
# 12   10-day streak        https://github.com/ryanchou-dev
# 13   10-day streak  https://www.github.com/MatthewStanciu
# 14   10-day streak        https://github.com/jianmin-chen
# 15    0-day streak    https://github.com/christinaasquith
# 16    1-day streak           https://github.com/SamDev-7/
# 17   10-day streak       https://github.com/rajanwastaken
# 18   11-day streak          https://github.com/l3gacyb3ta
# 19    0-day streak            https://github.com/sampoder
# 20    0-day streak            https://github.com/cedric-h
# 21   10-day streak               https://github.com/thrzl
# 22   10-day streak        https://github.com/maggie-j-liu
# 23    0-day streak      https://github.com/clairebookworm
# 24   12-day streak       https://github.com/YodaLightsabr
# 25   10-day streak     https://github.com/developedbytoby
# 26   11-day streak           https://github.com/kaidevrim
# 27   10-day streak           https://github.com/zachlatta
# 28    1-day streak           https://github.com/tildezero
# 29    1-day streak         https://github.com/CoolCoderSJ
#
#            GitHub UserName        GHusername  \
# 0                     sike        sikethedev
# 1         Laker J.V Turner              lxjv
# 2         Rizwan Nizarudin        StuntStorm
# 3                    Lucas         LucasHT22
# 4              Caleb Denio           cjdenio
# 5                 Skyascii       savioxavier
# 6   Javier Zaleta Martínez      javierzaleta
# 7                     Omay           Omay238
# 8            Aaryan Porwal      aaryanporwal
# 9           Bolun Thompson     BolunThompson
# 10            Linus Skucas       LinusSkucas
# 11                 Hugo Hu           Hugoyhu
# 12               Ryan Chou      ryanchou-dev
# 13         Matthew Stanciu    MatthewStanciu
# 14            Jianmin Chen      jianmin-chen
# 15       Christina Asquith  christinaasquith
# 16                 Sam Liu          SamDev-7
# 17           Rajan Agarwal     rajanwastaken
# 18             Arcade Wise        l3gacyb3ta
# 19               Sam Poder          sampoder
# 20        Cedric Hutchings          cedric-h
# 21                   terry             thrzl
# 22              Maggie Liu      maggie-j-liu
# 23             Claire Wang    ClaireBookworm
# 24           yodalightsabr     YodaLightsabr
# 25                    Toby   developedbytoby
# 26              Kai Devrim         KaiDevrim
# 27              zach latta         zachlatta
# 28                   suhas         tildezero
# 29            Shuchir Jain       CoolCoderSJ
#
#                                                 GHBio GHFollowers_y  \
# 0         Building projects that can change the world            19
# 1   She/her. Student by day, aspiring vampire by n...            21
# 2   Owner of StuntStorm Production || Indie Game D...            17
# 3   Head of @ge-ci and from one @hackclub in Sao P...             5
# 4                                       I code stuff.           158
# 5                 A very caffeine dependent life form            20
# 6   I'm a 18-year-old medical student, web develop...            40
# 7                                       coding is fun             7
# 8   A passionate developer, likes to work with imp...           103
# 9      My legal name is Aaron Bolun Thompson. He/him.             4
# 10   Making things with Swift, somewhere in Seattle 🌲            69
# 11  mail coordinator and special projects at hack ...            50
# 12                          crying and coding ≧(´▽｀)≦            30
# 13  ✨🚀👁 purdue 💻 prev. clubs @hackclub 🦕 he/him 🏳️...           152
# 14  I like to build tools that are fun or useful. ...             5
# 15  Hi, I'm a journalist and war correspondent-tur...            52
# 16                                      Hackin' away!            10
# 17  building cool stuff, meeting cooler people alo...            66
# 18        They/them, Linux, Pentesting, and Musicals!            63
# 19            experimenting and having fun with code!           328
# 20  “Every line of code is written without reason,...            97
# 21  i speak to crabs, snakes, gophers, decaf coffe...            24
# 22                            executive @cpinitiative           116
# 23  To the stars and beyond! 🚀\n<3er of @hackclub,...           192
# 24  websites, bots, developer tools, and other ran...            75
# 25  13 year old full stack web dev exploring & bui...            63
# 26  Part-Time High School Student,\nPart-Time Comp...           134
# 27                founder of @hackclub. hackin' away.           931
# 28                                            failure            18
# 29        I enjoy backend-dev, as well as photography            56
#
#     GHFollowing_y                                  GHContributions_y Result
# 0            44.0  545\n      contributions\n        in the last ...    Yes
# 1           125.0  331\n      contributions\n        in the last ...    Yes
# 2            12.0  838\n      contributions\n        in the last ...    Yes
# 3            22.0  245\n      contributions\n        in the last ...    Yes
# 4           143.0  1,708\n      contributions\n        in the las...    Yes
# 5             0.0  464\n      contributions\n        in the last ...    Yes
# 6            64.0  312\n      contributions\n        in the last ...    Yes
# 7            24.0  145\n      contributions\n        in the last ...    Yes
# 8            93.0  258\n      contributions\n        in the last ...    Yes
# 9             0.0  153\n      contributions\n        in the last ...    Yes
# 10           51.0  258\n      contributions\n        in the last ...    Yes
# 11           40.0  100\n      contributions\n        in the last ...    Yes
# 12           30.0  830\n      contributions\n        in the last ...    Yes
# 13           31.0  1,206\n      contributions\n        in the las...    Yes
# 14            0.0  480\n      contributions\n        in the last ...    Yes
# 15           21.0  50\n      contributions\n        in the last year    Yes
# 16            3.0  552\n      contributions\n        in the last ...    Yes
# 17          129.0  991\n      contributions\n        in the last ...    Yes
# 18           57.0  311\n      contributions\n        in the last ...    Yes
# 19          253.0  3,094\n      contributions\n        in the las...    Yes
# 20            6.0  821\n      contributions\n        in the last ...    Yes
# 21           24.0  504\n      contributions\n        in the last ...    Yes
# 22           41.0  1,693\n      contributions\n        in the las...    Yes
# 23          137.0  415\n      contributions\n        in the last ...    Yes
# 24           70.0  1,830\n      contributions\n        in the las...    Yes
# 25           46.0  1,135\n      contributions\n        in the las...    Yes
# 26          487.0  374\n      contributions\n        in the last ...    Yes
# 27          230.0  514\n      contributions\n        in the last ...    Yes
# 28           18.0  283\n      contributions\n        in the last ...    Yes
# 29           38.0  363\n      contributions\n        in the last ...    Yes
